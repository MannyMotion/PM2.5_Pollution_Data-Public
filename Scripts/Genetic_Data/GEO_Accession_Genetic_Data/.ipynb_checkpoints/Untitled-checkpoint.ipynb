# %%
import pandas as pd
import gzip

# 📍 Define the path to your gzipped scoring file
pgs_scoring_file = "C:/Users/emman/Downloads/PM2.5_Pollution_Data-Public/Scripts/Genetic_Data/GEO_Accession_Genetic_Data/PGS000018.txt.gz"

# 🔍 Preview the first few lines to inspect formatting
with gzip.open(pgs_scoring_file, 'rt') as f:
    for _ in range(20):  # Print first 20 lines to check for headers or malformed rows
        print(f.readline())

# ✅ Load the file using pandas with robust settings
df = pd.read_csv(
    pgs_scoring_file,         # File path
    sep='\t',                 # Tab-separated values
    compression='gzip',       # File is gzipped
    engine='python',          # More tolerant parser than default 'c'
    on_bad_lines='skip',       # Skip malformed lines instead of raising errors
    comment='#'
)

# 👀 Display the first few rows of the parsed DataFrame
print(df.head())
# Out:
# ###PGS CATALOG SCORING FILE - see https://www.pgscatalog.org/downloads/#dl_ftp_scoring for additional information
#
# #format_version=2.0
#
# ##POLYGENIC SCORE (PGS) INFORMATION
#
# #pgs_id=PGS000018
#
# #pgs_name=metaGRS_CAD
#
# #trait_reported=Coronary artery disease
#
# #trait_mapped=coronary artery disease
#
# #trait_efo=EFO_0001645
#
# #weight_type=NR
#
# #genome_build=hg19
#
# #variants_number=1745180
#
# ##SOURCE INFORMATION
#
# #pgp_id=PGP000007
#
# #citation=Inouye M et al. J Am Coll Cardiol (2018). doi:10.1016/j.jacc.2018.07.079
#
# rsID	chr_name	chr_position	effect_allele	other_allele	effect_weight
#
# rs2843152	1	2245570	G	C	-2.76009e-02
#
# rs35465346	1	22132518	G	A	2.39340e-02
#
# rs28470722	1	38386727	G	A	-1.74935e-02
#
# rs11206510	1	55496039	T	C	2.93005e-02
#
# rs9970807	1	56965664	C	T	4.70027e-02
#
#          rsID  chr_name  chr_position effect_allele other_allele  \
# 0   rs2843152         1       2245570             G            C
# 1  rs35465346         1      22132518             G            A
# 2  rs28470722         1      38386727             G            A
# 3  rs11206510         1      55496039             T            C
# 4   rs9970807         1      56965664             C            T
#
#    effect_weight
# 0      -0.027601
# 1       0.023934
# 2      -0.017493
# 3       0.029301
# 4       0.047003

# %%
import pandas as pd
# Define the path to your gzipped scoring file
pgs_scoring_file = "C:/Users/emman/Downloads/PM2.5_Pollution_Data-Public/Scripts/Genetic_Data/GEO_Accession_Genetic_Data/PGS000018.txt.gz"

#Load the file using pandas with robust settings
df = pd.read_csv(
    pgs_scoring_file, ## File path
    sep='\t', ## Tab-separated values
    compression='gzip', ## File is gzipped
    comment='#',         # Skip all comment lines starting with '#'
    engine='python', # More tolerant parser than default 'c'
    on_bad_lines='skip' # Skip malformed lines instead of raising errors
)

#Display the first few rows of the parsed DataFrame
print(df.head())
print(df.columns)
# Out:
#          rsID  chr_name  chr_position effect_allele other_allele  \
# 0   rs2843152         1       2245570             G            C
# 1  rs35465346         1      22132518             G            A
# 2  rs28470722         1      38386727             G            A
# 3  rs11206510         1      55496039             T            C
# 4   rs9970807         1      56965664             C            T
#
#    effect_weight
# 0      -0.027601
# 1       0.023934
# 2      -0.017493
# 3       0.029301
# 4       0.047003
# Index(['rsID', 'chr_name', 'chr_position', 'effect_allele', 'other_allele',
#        'effect_weight'],
#       dtype='object')

# %%
import pandas as pd
import gzip
from io import StringIO

#Define the path to your gzipped PGS file
pgs_scoring_file = "C:/Users/emman/Downloads/PM2.5_Pollution_Data-Public/Scripts/Genetic_Data/GEO_Accession_Genetic_Data/PGS000018.txt.gz"# Ensure this file is in your working directory

# Open the file and filter out metadata lines (starting with '#' or '##')
with gzip.open(pgs_scoring_file, 'rt') as f:
    # Read all lines, excluding those that start with '#' (common in PGS metadata)
    lines = [line for line in f if not line.startswith('#')]

# Convert the cleaned list of lines into a format pandas can read
# StringIO lets us treat the string as a file-like object
data = pd.read_csv(StringIO(''.join(lines)), sep='\t')

# Filter SNPs located on chromosome 1
chr1_snps = data[data['chr_name'] == 1]

# Filter SNPs located on chromosome 2
chr2_snps = data[data['chr_name'] == 2]

# Save chromosome 1 SNPs to a tab-separated file
chr1_snps.to_csv('PGS000018_chr1.txt', sep='\t', index=False)

# Save chromosome 2 SNPs to a tab-separated file
chr2_snps.to_csv('PGS000018_chr2.txt', sep='\t', index=False)

# %%
import pandas as pd
import requests

# Step 1: Download the panel file (if you haven't downloaded manually)
url = 'https://ftp.1000genomes.ebi.ac.uk/vol1/ftp/release/20130502/integrated_call_samples_v3.20130502.ALL.panel'
panel_file = 'integrated_call_samples_v3.20130502.ALL.panel'

response = requests.get(url)
with open(panel_file, 'wb') as f:
    f.write(response.content)

print("Panel file downloaded!")

# Step 2: Read panel file and extract GBR sample IDs
panel_df = pd.read_csv(panel_file, sep='\t')
gbr_samples = panel_df[panel_df['pop'] == 'GBR']
gbr_sample_ids = gbr_samples['sample'].tolist()

# Optional: save to a file
with open('GBR_sample_ids.txt', 'w') as f:
    for sample_id in gbr_sample_ids:
        f.write(sample_id + '\n')

print(f"Found {len(gbr_sample_ids)} GBR samples.")
print(gbr_sample_ids[:10])
# Out:
# Panel file downloaded!
# Found 91 GBR samples.
# ['HG00096', 'HG00097', 'HG00099', 'HG00100', 'HG00101', 'HG00102', 'HG00103', 'HG00105', 'HG00106', 'HG00107']

# %%
import pandas as pd
import gzip
import os

# Paths to files
vcf_path = 'ALL.chr1.phase3_shapeit2_mvncall_integrated_v5b.20130502.genotypes (1).vcf.gz'  # change if needed
if not os.path.isfile(vcf_path):
    print(f"❌ File not found: {vcf_path}")
    # Optionally, exit the script
    import sys
    sys.exit(1)
else:
    print(f"✅ File found: {vcf_path}")
    
pgs_path = 'PGS000018_chr1.txt'  # filtered PGS SNPs chr1 file
output_csv = 'chr1_genotype_dosage.csv'

# Load PGS SNP list
pgs_snps = pd.read_csv(pgs_path, sep='\t')


# Adjust this column name if your SNP ID column has a different name
pgs_snp_set = set(pgs_snps['rsID'])  

target_samples = ['HG00119', 'HG00121']  # Samples of interest

records = []

with gzip.open(vcf_path, 'rt', encoding='utf-8', errors='ignore') as f:
    for line in f:
        if line.startswith('##'):
            continue  # Skip metadata

        if line.startswith('#CHROM'):
            header = line.strip().split('\t')
            # Find indices of target samples in the VCF
            sample_indices = [header.index(s) for s in target_samples]
            continue

        fields = line.strip().split('\t')
        chrom = fields[0]
        pos = fields[1]
        snp_id = fields[2]
        ref = fields[3]
        alt = fields[4]

        # Filter to keep only SNPs in your PGS list
        if snp_id not in pgs_snp_set:
            continue

        format_fields = fields[8].split(':')
        # Get index of GT (genotype) field
        try:
            gt_index = format_fields.index('GT')
        except ValueError:
            continue  # skip if GT not found

        for idx in sample_indices:
            sample = header[idx]
            sample_data = fields[idx].split(':')
            gt = sample_data[gt_index]

            if '.' in gt:
                dosage = None  # missing genotype
            else:
                # Handle phased/unphased genotype: e.g. 0|1 or 0/1
                alleles = gt.replace('|', '/').split('/')
                dosage = sum(int(a) for a in alleles)

            records.append({
                'CHROM': chrom,
                'POS': int(pos),
                'SNP': snp_id,
                'REF': ref,
                'ALT': alt,
                'Sample': sample,
                'Dosage': dosage
            })

# Convert to DataFrame and save
geno_df = pd.DataFrame(records)
geno_df.to_csv(output_csv, index=False)
print(f"✅ Genotype dosage extraction complete. Saved to {output_csv}")
# Out:
# ✅ File found: ALL.chr1.phase3_shapeit2_mvncall_integrated_v5b.20130502.genotypes (1).vcf.gz

# %%
# Step 5 - Harmonize alleles between PGS and Genotypes Data 
import pandas as pd #Import the pandas library for data manipulation

def complement(base):#Define a helper function to return the complement of a DNA base (used for strand flipping)
    """Return the complement base (strand flip)"""
    comp = {'A':'T', 'T':'A', 'C':'G', 'G':'C'} #DNA base pairing rules
    return comp.get(base.upper(), base)# Return complement or original if not A/T/C/G

def check_allele_match(pgs_eff, pgs_oth, ref, alt):#Define a function to check how alleles from PGS and genotype data align
    """
    Check allele matching and flipping status:
    - match: effect_allele == ALT and other_allele == REF
    - flip: effect_allele == REF and other_allele == ALT
    - strand_flip_match: complement(effect_allele) == ALT and complement(other_allele) == REF
    - strand_flip_flip: complement(effect_allele) == REF and complement(other_allele) == ALT
    - mismatch: none of above
    """
    #Convert all alleles to uppercase for consistency
    pgs_eff = pgs_eff.upper()
    pgs_oth = pgs_oth.upper()
    ref = ref.upper()
    alt = alt.upper()

    if pgs_eff == alt and pgs_oth == ref:#Direct match
        return 'match'
    elif pgs_eff == ref and pgs_oth == alt:#Reversed alleles
        return 'flip'
    elif complement(pgs_eff) == alt and complement(pgs_oth) == ref:#Match after strand flipping
        return 'strand_flip_match'
    elif complement(pgs_eff) == ref and complement(pgs_oth) == alt:#Flip after strand flipping
        return 'strand_flip_flip'
    else:#No valid match
        return 'mismatch'

def flip_dosage(dosage):#Define a function to flip genotype dosage values
    """
    Flip genotype dosage from ALT allele to REF allele count.
    VCF dosage: 0=hom_ref,1=het,2=hom_alt
    Flipped dosage: 2 - dosage
    """
    return 2 - dosage

def harmonize_alleles(pgs_df, geno_df):  # Main function to harmonize alleles between PGS and genotype data
    """
    Harmonize alleles between PGS and genotype data.
    Returns DataFrame with SNP, harmonized dosage, harmonized effect_weight.
    """
    harmonized = []  # empty list variable to store harmonized results

    # Convert SNPs in genotype chunk to set for faster lookup
    geno_snps = set(geno_df['SNP'])

    # Filter PGS dataframe to only SNPs present in this genotype chunk
    pgs_subset = pgs_df[pgs_df['SNP'].isin(geno_snps)]

    # Remove this unused line to avoid error:
    # geno_dict = geno_chunk.set_index('SNP').to_dict('index')

    # Loop through each SNP in the PGS subset (only SNPs present in genotype chunk)
    for idx, row in pgs_subset.iterrows():
        snp = row['SNP']
        pgs_eff = row['effect_allele']
        pgs_oth = row['other_allele']
        effect_weight = row['effect_weight']

        # Get genotype data for SNP
        vcf_row = geno_df[geno_df['SNP'] == snp]
        if vcf_row.empty:
            continue  # SNP not found in genotype data, skip

        # Extract reference and alternate alleles and dosage
        ref = vcf_row['REF'].values[0]
        alt = vcf_row['ALT'].values[0]
        dosage = vcf_row['dosage'].values[0]

        if pd.isna(dosage):
            continue

        status = check_allele_match(pgs_eff, pgs_oth, ref, alt)

        if status == 'match' or status == 'strand_flip_match':
            harmonized.append({'SNP': snp, 'dosage': dosage, 'effect_weight': effect_weight})
        elif status == 'flip' or status == 'strand_flip_flip':
            flipped_dosage = flip_dosage(dosage)
            harmonized.append({'SNP': snp, 'dosage': flipped_dosage, 'effect_weight': effect_weight})
        else:
            continue  # mismatch or ambiguous allele - skip

    harmonized_df = pd.DataFrame(harmonized)
    return harmonized_df

    

#Example usage:
#Load PGS data - make sure columns: 'rsID', 'effect_allele', 'other_allele', 'effect_weight'
#Load PGS data with correct column names
pgs_df = pd.read_csv('PGS000018_chr1.txt', sep='\t', usecols=['rsID', 'effect_allele', 'other_allele', 'effect_weight'])

# Rename 'rsID' column to 'SNP' to match rest of your code
pgs_df.rename(columns={'rsID': 'SNP'}, inplace=True)

# Prepare to process genotype data in chunks
chunksize = 10000  # adjust this based on your RAM
harmonized_chunks = []

# Read genotype dosage file chunk by chunk
for i, geno_chunk in enumerate(pd.read_csv('chr1_genotype_dosage.csv', chunksize=chunksize)):
    harmonized_chunk = harmonize_alleles(pgs_df, geno_chunk)
    print(f"Chunk {i}: harmonized_chunk shape = {harmonized_chunk.shape}")  # debug output
    if not harmonized_chunk.empty:
        harmonized_chunks.append(harmonized_chunk)

    
# Concatenate all harmonized chunks
if harmonized_chunks:  # Only concat if list is non-empty
    harmonized_df = pd.concat(harmonized_chunks, ignore_index=True)
    
    # Check if columns exist before computing weighted score
    if 'dosage' in harmonized_df.columns and 'effect_weight' in harmonized_df.columns:
        harmonized_df['weighted_score'] = harmonized_df['dosage'] * harmonized_df['effect_weight']
        total_score = harmonized_df['weighted_score'].sum()
        print(f"Polygenic Score: {total_score}")
    else:
        print("Columns 'dosage' or 'effect_weight' missing from harmonized data.")
else:
    print("No harmonized data found in any chunk. Nothing to concatenate.")


# Sum over all SNPs for an individual's PGS
total_score = harmonized_df['weighted_score'].sum()

print(f"Polygenic Score: {total_score}")
# Out:
# Chunk 0: harmonized_chunk shape = (0, 0)
# Chunk 1: harmonized_chunk shape = (0, 0)
# Chunk 2: harmonized_chunk shape = (0, 0)
# Chunk 3: harmonized_chunk shape = (0, 0)
# Chunk 4: harmonized_chunk shape = (0, 0)
# Chunk 5: harmonized_chunk shape = (0, 0)
# Chunk 6: harmonized_chunk shape = (0, 0)
# Chunk 7: harmonized_chunk shape = (0, 0)
# Chunk 8: harmonized_chunk shape = (0, 0)
# Chunk 9: harmonized_chunk shape = (0, 0)
# Chunk 10: harmonized_chunk shape = (0, 0)
# Chunk 11: harmonized_chunk shape = (0, 0)
# Chunk 12: harmonized_chunk shape = (0, 0)
# Chunk 13: harmonized_chunk shape = (0, 0)
# Chunk 14: harmonized_chunk shape = (0, 0)
# Chunk 15: harmonized_chunk shape = (0, 0)
# Chunk 16: harmonized_chunk shape = (0, 0)
# Chunk 17: harmonized_chunk shape = (0, 0)
# Chunk 18: harmonized_chunk shape = (0, 0)
# Chunk 19: harmonized_chunk shape = (0, 0)
# Chunk 20: harmonized_chunk shape = (0, 0)
# Chunk 21: harmonized_chunk shape = (0, 0)
# Chunk 22: harmonized_chunk shape = (0, 0)
# Chunk 23: harmonized_chunk shape = (0, 0)
# Chunk 24: harmonized_chunk shape = (0, 0)
# Chunk 25: harmonized_chunk shape = (0, 0)
# Chunk 26: harmonized_chunk shape = (0, 0)
# Chunk 27: harmonized_chunk shape = (0, 0)
# Chunk 28: harmonized_chunk shape = (0, 0)
# Chunk 29: harmonized_chunk shape = (0, 0)
# Chunk 30: harmonized_chunk shape = (0, 0)
# Chunk 31: harmonized_chunk shape = (0, 0)
# Chunk 32: harmonized_chunk shape = (0, 0)
# Chunk 33: harmonized_chunk shape = (0, 0)
# Chunk 34: harmonized_chunk shape = (0, 0)
# Chunk 35: harmonized_chunk shape = (0, 0)
# Chunk 36: harmonized_chunk shape = (0, 0)
# Chunk 37: harmonized_chunk shape = (0, 0)
# Chunk 38: harmonized_chunk shape = (0, 0)
# Chunk 39: harmonized_chunk shape = (0, 0)
# Chunk 40: harmonized_chunk shape = (0, 0)
# Chunk 41: harmonized_chunk shape = (0, 0)
# Chunk 42: harmonized_chunk shape = (0, 0)
# Chunk 43: harmonized_chunk shape = (0, 0)
# Chunk 44: harmonized_chunk shape = (0, 0)
# Chunk 45: harmonized_chunk shape = (0, 0)
# Chunk 46: harmonized_chunk shape = (0, 0)
# Chunk 47: harmonized_chunk shape = (0, 0)
# Chunk 48: harmonized_chunk shape = (0, 0)
# Chunk 49: harmonized_chunk shape = (0, 0)
# Chunk 50: harmonized_chunk shape = (0, 0)
# Chunk 51: harmonized_chunk shape = (0, 0)
# Chunk 52: harmonized_chunk shape = (0, 0)
# Chunk 53: harmonized_chunk shape = (0, 0)
# Chunk 54: harmonized_chunk shape = (0, 0)
# Chunk 55: harmonized_chunk shape = (0, 0)
# Chunk 56: harmonized_chunk shape = (0, 0)
# Chunk 57: harmonized_chunk shape = (0, 0)
# Chunk 58: harmonized_chunk shape = (0, 0)
# Chunk 59: harmonized_chunk shape = (0, 0)
# Chunk 60: harmonized_chunk shape = (0, 0)
# Chunk 61: harmonized_chunk shape = (0, 0)
# Chunk 62: harmonized_chunk shape = (0, 0)
# Chunk 63: harmonized_chunk shape = (0, 0)
# Chunk 64: harmonized_chunk shape = (0, 0)
# Chunk 65: harmonized_chunk shape = (0, 0)
# Chunk 66: harmonized_chunk shape = (0, 0)
# Chunk 67: harmonized_chunk shape = (0, 0)
# Chunk 68: harmonized_chunk shape = (0, 0)
# Chunk 69: harmonized_chunk shape = (0, 0)
# Chunk 70: harmonized_chunk shape = (0, 0)
# Chunk 71: harmonized_chunk shape = (0, 0)
# Chunk 72: harmonized_chunk shape = (0, 0)
# Chunk 73: harmonized_chunk shape = (0, 0)
# Chunk 74: harmonized_chunk shape = (0, 0)
# Chunk 75: harmonized_chunk shape = (0, 0)
# Chunk 76: harmonized_chunk shape = (0, 0)
# Chunk 77: harmonized_chunk shape = (0, 0)
# Chunk 78: harmonized_chunk shape = (0, 0)
# Chunk 79: harmonized_chunk shape = (0, 0)
# Chunk 80: harmonized_chunk shape = (0, 0)
# Chunk 81: harmonized_chunk shape = (0, 0)
# Chunk 82: harmonized_chunk shape = (0, 0)
# Chunk 83: harmonized_chunk shape = (0, 0)
# Chunk 84: harmonized_chunk shape = (0, 0)
# Chunk 85: harmonized_chunk shape = (0, 0)
# Chunk 86: harmonized_chunk shape = (0, 0)
# Chunk 87: harmonized_chunk shape = (0, 0)
# Chunk 88: harmonized_chunk shape = (0, 0)
# Chunk 89: harmonized_chunk shape = (0, 0)
# Chunk 90: harmonized_chunk shape = (0, 0)
# Chunk 91: harmonized_chunk shape = (0, 0)
# Chunk 92: harmonized_chunk shape = (0, 0)
# Chunk 93: harmonized_chunk shape = (0, 0)
# Chunk 94: harmonized_chunk shape = (0, 0)
# Chunk 95: harmonized_chunk shape = (0, 0)
# Chunk 96: harmonized_chunk shape = (0, 0)
# Chunk 97: harmonized_chunk shape = (0, 0)
# Chunk 98: harmonized_chunk shape = (0, 0)
# Chunk 99: harmonized_chunk shape = (0, 0)
# Chunk 100: harmonized_chunk shape = (0, 0)
# Chunk 101: harmonized_chunk shape = (0, 0)
# Chunk 102: harmonized_chunk shape = (0, 0)
# Chunk 103: harmonized_chunk shape = (0, 0)
# Chunk 104: harmonized_chunk shape = (0, 0)
# Chunk 105: harmonized_chunk shape = (0, 0)
# Chunk 106: harmonized_chunk shape = (0, 0)
# Chunk 107: harmonized_chunk shape = (0, 0)
# Chunk 108: harmonized_chunk shape = (0, 0)
# Chunk 109: harmonized_chunk shape = (0, 0)
# Chunk 110: harmonized_chunk shape = (0, 0)
# Chunk 111: harmonized_chunk shape = (0, 0)
# Chunk 112: harmonized_chunk shape = (0, 0)
# Chunk 113: harmonized_chunk shape = (0, 0)
# Chunk 114: harmonized_chunk shape = (0, 0)
# Chunk 115: harmonized_chunk shape = (0, 0)
# Chunk 116: harmonized_chunk shape = (0, 0)
# Chunk 117: harmonized_chunk shape = (0, 0)
# Chunk 118: harmonized_chunk shape = (0, 0)
# Chunk 119: harmonized_chunk shape = (0, 0)
# Chunk 120: harmonized_chunk shape = (0, 0)
# Chunk 121: harmonized_chunk shape = (0, 0)
# Chunk 122: harmonized_chunk shape = (0, 0)
# Chunk 123: harmonized_chunk shape = (0, 0)
# Chunk 124: harmonized_chunk shape = (0, 0)
# Chunk 125: harmonized_chunk shape = (0, 0)
# Chunk 126: harmonized_chunk shape = (0, 0)
# Chunk 127: harmonized_chunk shape = (0, 0)
# Chunk 128: harmonized_chunk shape = (0, 0)
# Chunk 129: harmonized_chunk shape = (0, 0)
# Chunk 130: harmonized_chunk shape = (0, 0)
# Chunk 131: harmonized_chunk shape = (0, 0)
# Chunk 132: harmonized_chunk shape = (0, 0)
# Chunk 133: harmonized_chunk shape = (0, 0)
# Chunk 134: harmonized_chunk shape = (0, 0)
# Chunk 135: harmonized_chunk shape = (0, 0)
# Chunk 136: harmonized_chunk shape = (0, 0)
# Chunk 137: harmonized_chunk shape = (0, 0)
# Chunk 138: harmonized_chunk shape = (0, 0)
# Chunk 139: harmonized_chunk shape = (0, 0)
# Chunk 140: harmonized_chunk shape = (0, 0)
# Chunk 141: harmonized_chunk shape = (0, 0)
# Chunk 142: harmonized_chunk shape = (0, 0)
# Chunk 143: harmonized_chunk shape = (0, 0)
# Chunk 144: harmonized_chunk shape = (0, 0)
# Chunk 145: harmonized_chunk shape = (0, 0)
# Chunk 146: harmonized_chunk shape = (0, 0)
# Chunk 147: harmonized_chunk shape = (0, 0)
# Chunk 148: harmonized_chunk shape = (0, 0)
# Chunk 149: harmonized_chunk shape = (0, 0)
# Chunk 150: harmonized_chunk shape = (0, 0)
# Chunk 151: harmonized_chunk shape = (0, 0)
# Chunk 152: harmonized_chunk shape = (0, 0)
# Chunk 153: harmonized_chunk shape = (0, 0)
# Chunk 154: harmonized_chunk shape = (0, 0)
# Chunk 155: harmonized_chunk shape = (0, 0)
# Chunk 156: harmonized_chunk shape = (0, 0)
# Chunk 157: harmonized_chunk shape = (0, 0)
# Chunk 158: harmonized_chunk shape = (0, 0)
# Chunk 159: harmonized_chunk shape = (0, 0)
# Chunk 160: harmonized_chunk shape = (0, 0)
# Chunk 161: harmonized_chunk shape = (0, 0)
# Chunk 162: harmonized_chunk shape = (0, 0)
# Chunk 163: harmonized_chunk shape = (0, 0)
# Chunk 164: harmonized_chunk shape = (0, 0)
# Chunk 165: harmonized_chunk shape = (0, 0)
# Chunk 166: harmonized_chunk shape = (0, 0)
# Chunk 167: harmonized_chunk shape = (0, 0)
# Chunk 168: harmonized_chunk shape = (0, 0)
# Chunk 169: harmonized_chunk shape = (0, 0)
# Chunk 170: harmonized_chunk shape = (0, 0)
# Chunk 171: harmonized_chunk shape = (0, 0)
# Chunk 172: harmonized_chunk shape = (0, 0)
# Chunk 173: harmonized_chunk shape = (0, 0)
# Chunk 174: harmonized_chunk shape = (0, 0)
# Chunk 175: harmonized_chunk shape = (0, 0)
# Chunk 176: harmonized_chunk shape = (0, 0)
# Chunk 177: harmonized_chunk shape = (0, 0)
# Chunk 178: harmonized_chunk shape = (0, 0)
# Chunk 179: harmonized_chunk shape = (0, 0)
# Chunk 180: harmonized_chunk shape = (0, 0)
# Chunk 181: harmonized_chunk shape = (0, 0)
# Chunk 182: harmonized_chunk shape = (0, 0)
# Chunk 183: harmonized_chunk shape = (0, 0)
# Chunk 184: harmonized_chunk shape = (0, 0)
# Chunk 185: harmonized_chunk shape = (0, 0)
# Chunk 186: harmonized_chunk shape = (0, 0)
# Chunk 187: harmonized_chunk shape = (0, 0)
# Chunk 188: harmonized_chunk shape = (0, 0)
# Chunk 189: harmonized_chunk shape = (0, 0)
# Chunk 190: harmonized_chunk shape = (0, 0)
# Chunk 191: harmonized_chunk shape = (0, 0)
# Chunk 192: harmonized_chunk shape = (0, 0)
# Chunk 193: harmonized_chunk shape = (0, 0)
# Chunk 194: harmonized_chunk shape = (0, 0)
# Chunk 195: harmonized_chunk shape = (0, 0)
# Chunk 196: harmonized_chunk shape = (0, 0)
# Chunk 197: harmonized_chunk shape = (0, 0)
# Chunk 198: harmonized_chunk shape = (0, 0)
# Chunk 199: harmonized_chunk shape = (0, 0)
# Chunk 200: harmonized_chunk shape = (0, 0)
# Chunk 201: harmonized_chunk shape = (0, 0)
# Chunk 202: harmonized_chunk shape = (0, 0)
# Chunk 203: harmonized_chunk shape = (0, 0)
# Chunk 204: harmonized_chunk shape = (0, 0)
# Chunk 205: harmonized_chunk shape = (0, 0)
# Chunk 206: harmonized_chunk shape = (0, 0)
# Chunk 207: harmonized_chunk shape = (0, 0)
# Chunk 208: harmonized_chunk shape = (0, 0)
# Chunk 209: harmonized_chunk shape = (0, 0)
# Chunk 210: harmonized_chunk shape = (0, 0)
# Chunk 211: harmonized_chunk shape = (0, 0)
# Chunk 212: harmonized_chunk shape = (0, 0)
# Chunk 213: harmonized_chunk shape = (0, 0)
# Chunk 214: harmonized_chunk shape = (0, 0)
# Chunk 215: harmonized_chunk shape = (0, 0)
# Chunk 216: harmonized_chunk shape = (0, 0)
# Chunk 217: harmonized_chunk shape = (0, 0)
# Chunk 218: harmonized_chunk shape = (0, 0)
# Chunk 219: harmonized_chunk shape = (0, 0)
# Chunk 220: harmonized_chunk shape = (0, 0)
# Chunk 221: harmonized_chunk shape = (0, 0)
# Chunk 222: harmonized_chunk shape = (0, 0)
# Chunk 223: harmonized_chunk shape = (0, 0)
# Chunk 224: harmonized_chunk shape = (0, 0)
# Chunk 225: harmonized_chunk shape = (0, 0)
# Chunk 226: harmonized_chunk shape = (0, 0)
# Chunk 227: harmonized_chunk shape = (0, 0)
# Chunk 228: harmonized_chunk shape = (0, 0)
# Chunk 229: harmonized_chunk shape = (0, 0)
# Chunk 230: harmonized_chunk shape = (0, 0)
# Chunk 231: harmonized_chunk shape = (0, 0)
# Chunk 232: harmonized_chunk shape = (0, 0)
# Chunk 233: harmonized_chunk shape = (0, 0)
# Chunk 234: harmonized_chunk shape = (0, 0)
# Chunk 235: harmonized_chunk shape = (0, 0)
# Chunk 236: harmonized_chunk shape = (0, 0)
# Chunk 237: harmonized_chunk shape = (0, 0)
# Chunk 238: harmonized_chunk shape = (0, 0)
# Chunk 239: harmonized_chunk shape = (0, 0)
# Chunk 240: harmonized_chunk shape = (0, 0)
# Chunk 241: harmonized_chunk shape = (0, 0)
# Chunk 242: harmonized_chunk shape = (0, 0)
# Chunk 243: harmonized_chunk shape = (0, 0)
# Chunk 244: harmonized_chunk shape = (0, 0)
# Chunk 245: harmonized_chunk shape = (0, 0)
# Chunk 246: harmonized_chunk shape = (0, 0)
# Chunk 247: harmonized_chunk shape = (0, 0)
# Chunk 248: harmonized_chunk shape = (0, 0)
# Chunk 249: harmonized_chunk shape = (0, 0)
# Chunk 250: harmonized_chunk shape = (0, 0)
# Chunk 251: harmonized_chunk shape = (0, 0)
# Chunk 252: harmonized_chunk shape = (0, 0)
# Chunk 253: harmonized_chunk shape = (0, 0)
# Chunk 254: harmonized_chunk shape = (0, 0)
# Chunk 255: harmonized_chunk shape = (0, 0)
# Chunk 256: harmonized_chunk shape = (0, 0)
# Chunk 257: harmonized_chunk shape = (0, 0)
# Chunk 258: harmonized_chunk shape = (0, 0)
# Chunk 259: harmonized_chunk shape = (0, 0)
# Chunk 260: harmonized_chunk shape = (0, 0)
# Chunk 261: harmonized_chunk shape = (0, 0)
# Chunk 262: harmonized_chunk shape = (0, 0)
# Chunk 263: harmonized_chunk shape = (0, 0)
# Chunk 264: harmonized_chunk shape = (0, 0)
# Chunk 265: harmonized_chunk shape = (0, 0)
# Chunk 266: harmonized_chunk shape = (0, 0)
# Chunk 267: harmonized_chunk shape = (0, 0)
# Chunk 268: harmonized_chunk shape = (0, 0)
# Chunk 269: harmonized_chunk shape = (0, 0)
# Chunk 270: harmonized_chunk shape = (0, 0)
# Chunk 271: harmonized_chunk shape = (0, 0)
# Chunk 272: harmonized_chunk shape = (0, 0)
# Chunk 273: harmonized_chunk shape = (0, 0)
# Chunk 274: harmonized_chunk shape = (0, 0)
# Chunk 275: harmonized_chunk shape = (0, 0)
# Chunk 276: harmonized_chunk shape = (0, 0)
# Chunk 277: harmonized_chunk shape = (0, 0)
# Chunk 278: harmonized_chunk shape = (0, 0)
# Chunk 279: harmonized_chunk shape = (0, 0)
# Chunk 280: harmonized_chunk shape = (0, 0)
# Chunk 281: harmonized_chunk shape = (0, 0)
# Chunk 282: harmonized_chunk shape = (0, 0)
# Chunk 283: harmonized_chunk shape = (0, 0)
# Chunk 284: harmonized_chunk shape = (0, 0)
# Chunk 285: harmonized_chunk shape = (0, 0)
# Chunk 286: harmonized_chunk shape = (0, 0)
# Chunk 287: harmonized_chunk shape = (0, 0)
# Chunk 288: harmonized_chunk shape = (0, 0)
# Chunk 289: harmonized_chunk shape = (0, 0)
# Chunk 290: harmonized_chunk shape = (0, 0)
# Chunk 291: harmonized_chunk shape = (0, 0)
# Chunk 292: harmonized_chunk shape = (0, 0)
# Chunk 293: harmonized_chunk shape = (0, 0)
# Chunk 294: harmonized_chunk shape = (0, 0)
# Chunk 295: harmonized_chunk shape = (0, 0)
# Chunk 296: harmonized_chunk shape = (0, 0)
# Chunk 297: harmonized_chunk shape = (0, 0)
# Chunk 298: harmonized_chunk shape = (0, 0)
# Chunk 299: harmonized_chunk shape = (0, 0)
# Chunk 300: harmonized_chunk shape = (0, 0)
# Chunk 301: harmonized_chunk shape = (0, 0)
# Chunk 302: harmonized_chunk shape = (0, 0)
# Chunk 303: harmonized_chunk shape = (0, 0)
# Chunk 304: harmonized_chunk shape = (0, 0)
# Chunk 305: harmonized_chunk shape = (0, 0)
# Chunk 306: harmonized_chunk shape = (0, 0)
# Chunk 307: harmonized_chunk shape = (0, 0)
# Chunk 308: harmonized_chunk shape = (0, 0)
# Chunk 309: harmonized_chunk shape = (0, 0)
# Chunk 310: harmonized_chunk shape = (0, 0)
# Chunk 311: harmonized_chunk shape = (0, 0)
# Chunk 312: harmonized_chunk shape = (0, 0)
# Chunk 313: harmonized_chunk shape = (0, 0)
# Chunk 314: harmonized_chunk shape = (0, 0)
# Chunk 315: harmonized_chunk shape = (0, 0)
# Chunk 316: harmonized_chunk shape = (0, 0)
# Chunk 317: harmonized_chunk shape = (0, 0)
# Chunk 318: harmonized_chunk shape = (0, 0)
# Chunk 319: harmonized_chunk shape = (0, 0)
# Chunk 320: harmonized_chunk shape = (0, 0)
# Chunk 321: harmonized_chunk shape = (0, 0)
# Chunk 322: harmonized_chunk shape = (0, 0)
# Chunk 323: harmonized_chunk shape = (0, 0)
# Chunk 324: harmonized_chunk shape = (0, 0)
# Chunk 325: harmonized_chunk shape = (0, 0)
# Chunk 326: harmonized_chunk shape = (0, 0)
# Chunk 327: harmonized_chunk shape = (0, 0)
# Chunk 328: harmonized_chunk shape = (0, 0)
# Chunk 329: harmonized_chunk shape = (0, 0)
# Chunk 330: harmonized_chunk shape = (0, 0)
# Chunk 331: harmonized_chunk shape = (0, 0)
# Chunk 332: harmonized_chunk shape = (0, 0)
# Chunk 333: harmonized_chunk shape = (0, 0)
# Chunk 334: harmonized_chunk shape = (0, 0)
# Chunk 335: harmonized_chunk shape = (0, 0)
# Chunk 336: harmonized_chunk shape = (0, 0)
# Chunk 337: harmonized_chunk shape = (0, 0)
# Chunk 338: harmonized_chunk shape = (0, 0)
# Chunk 339: harmonized_chunk shape = (0, 0)
# Chunk 340: harmonized_chunk shape = (0, 0)
# Chunk 341: harmonized_chunk shape = (0, 0)
# Chunk 342: harmonized_chunk shape = (0, 0)
# Chunk 343: harmonized_chunk shape = (0, 0)
# Chunk 344: harmonized_chunk shape = (0, 0)
# Chunk 345: harmonized_chunk shape = (0, 0)
# Chunk 346: harmonized_chunk shape = (0, 0)
# Chunk 347: harmonized_chunk shape = (0, 0)
# Chunk 348: harmonized_chunk shape = (0, 0)
# Chunk 349: harmonized_chunk shape = (0, 0)
# Chunk 350: harmonized_chunk shape = (0, 0)
# Chunk 351: harmonized_chunk shape = (0, 0)
# Chunk 352: harmonized_chunk shape = (0, 0)
# Chunk 353: harmonized_chunk shape = (0, 0)
# Chunk 354: harmonized_chunk shape = (0, 0)
# Chunk 355: harmonized_chunk shape = (0, 0)
# Chunk 356: harmonized_chunk shape = (0, 0)
# Chunk 357: harmonized_chunk shape = (0, 0)
# Chunk 358: harmonized_chunk shape = (0, 0)
# Chunk 359: harmonized_chunk shape = (0, 0)
# Chunk 360: harmonized_chunk shape = (0, 0)
# Chunk 361: harmonized_chunk shape = (0, 0)
# Chunk 362: harmonized_chunk shape = (0, 0)
# Chunk 363: harmonized_chunk shape = (0, 0)
# Chunk 364: harmonized_chunk shape = (0, 0)
# Chunk 365: harmonized_chunk shape = (0, 0)
# Chunk 366: harmonized_chunk shape = (0, 0)
# Chunk 367: harmonized_chunk shape = (0, 0)
# Chunk 368: harmonized_chunk shape = (0, 0)
# Chunk 369: harmonized_chunk shape = (0, 0)
# Chunk 370: harmonized_chunk shape = (0, 0)
# Chunk 371: harmonized_chunk shape = (0, 0)
# Chunk 372: harmonized_chunk shape = (0, 0)
# Chunk 373: harmonized_chunk shape = (0, 0)
# Chunk 374: harmonized_chunk shape = (0, 0)
# Chunk 375: harmonized_chunk shape = (0, 0)
# Chunk 376: harmonized_chunk shape = (0, 0)
# Chunk 377: harmonized_chunk shape = (0, 0)
# Chunk 378: harmonized_chunk shape = (0, 0)
# Chunk 379: harmonized_chunk shape = (0, 0)
# Chunk 380: harmonized_chunk shape = (0, 0)
# Chunk 381: harmonized_chunk shape = (0, 0)
# Chunk 382: harmonized_chunk shape = (0, 0)
# Chunk 383: harmonized_chunk shape = (0, 0)
# Chunk 384: harmonized_chunk shape = (0, 0)
# Chunk 385: harmonized_chunk shape = (0, 0)
# Chunk 386: harmonized_chunk shape = (0, 0)
# Chunk 387: harmonized_chunk shape = (0, 0)
# Chunk 388: harmonized_chunk shape = (0, 0)
# Chunk 389: harmonized_chunk shape = (0, 0)
# Chunk 390: harmonized_chunk shape = (0, 0)
# Chunk 391: harmonized_chunk shape = (0, 0)
# Chunk 392: harmonized_chunk shape = (0, 0)
# Chunk 393: harmonized_chunk shape = (0, 0)
# Chunk 394: harmonized_chunk shape = (0, 0)
# Chunk 395: harmonized_chunk shape = (0, 0)
# Chunk 396: harmonized_chunk shape = (0, 0)
# Chunk 397: harmonized_chunk shape = (0, 0)
# Chunk 398: harmonized_chunk shape = (0, 0)
# Chunk 399: harmonized_chunk shape = (0, 0)
# Chunk 400: harmonized_chunk shape = (0, 0)
# Chunk 401: harmonized_chunk shape = (0, 0)
# Chunk 402: harmonized_chunk shape = (0, 0)
# Chunk 403: harmonized_chunk shape = (0, 0)
# Chunk 404: harmonized_chunk shape = (0, 0)
# Chunk 405: harmonized_chunk shape = (0, 0)
# Chunk 406: harmonized_chunk shape = (0, 0)
# Chunk 407: harmonized_chunk shape = (0, 0)
# Chunk 408: harmonized_chunk shape = (0, 0)
# Chunk 409: harmonized_chunk shape = (0, 0)
# Chunk 410: harmonized_chunk shape = (0, 0)
# Chunk 411: harmonized_chunk shape = (0, 0)
# Chunk 412: harmonized_chunk shape = (0, 0)
# Chunk 413: harmonized_chunk shape = (0, 0)
# Chunk 414: harmonized_chunk shape = (0, 0)
# Chunk 415: harmonized_chunk shape = (0, 0)
# Chunk 416: harmonized_chunk shape = (0, 0)
# Chunk 417: harmonized_chunk shape = (0, 0)
# Chunk 418: harmonized_chunk shape = (0, 0)
# Chunk 419: harmonized_chunk shape = (0, 0)
# Chunk 420: harmonized_chunk shape = (0, 0)
# Chunk 421: harmonized_chunk shape = (0, 0)
# Chunk 422: harmonized_chunk shape = (0, 0)
# Chunk 423: harmonized_chunk shape = (0, 0)
# Chunk 424: harmonized_chunk shape = (0, 0)
# Chunk 425: harmonized_chunk shape = (0, 0)
# Chunk 426: harmonized_chunk shape = (0, 0)
# Chunk 427: harmonized_chunk shape = (0, 0)
# Chunk 428: harmonized_chunk shape = (0, 0)
# Chunk 429: harmonized_chunk shape = (0, 0)
# Chunk 430: harmonized_chunk shape = (0, 0)
# Chunk 431: harmonized_chunk shape = (0, 0)
# Chunk 432: harmonized_chunk shape = (0, 0)
# Chunk 433: harmonized_chunk shape = (0, 0)
# Chunk 434: harmonized_chunk shape = (0, 0)
# Chunk 435: harmonized_chunk shape = (0, 0)
# Chunk 436: harmonized_chunk shape = (0, 0)
# Chunk 437: harmonized_chunk shape = (0, 0)
# Chunk 438: harmonized_chunk shape = (0, 0)
# Chunk 439: harmonized_chunk shape = (0, 0)
# Chunk 440: harmonized_chunk shape = (0, 0)
# Chunk 441: harmonized_chunk shape = (0, 0)
# Chunk 442: harmonized_chunk shape = (0, 0)
# Chunk 443: harmonized_chunk shape = (0, 0)
# Chunk 444: harmonized_chunk shape = (0, 0)
# Chunk 445: harmonized_chunk shape = (0, 0)
# Chunk 446: harmonized_chunk shape = (0, 0)
# Chunk 447: harmonized_chunk shape = (0, 0)
# Chunk 448: harmonized_chunk shape = (0, 0)
# Chunk 449: harmonized_chunk shape = (0, 0)
# Chunk 450: harmonized_chunk shape = (0, 0)
# Chunk 451: harmonized_chunk shape = (0, 0)
# Chunk 452: harmonized_chunk shape = (0, 0)
# Chunk 453: harmonized_chunk shape = (0, 0)
# Chunk 454: harmonized_chunk shape = (0, 0)
# Chunk 455: harmonized_chunk shape = (0, 0)
# Chunk 456: harmonized_chunk shape = (0, 0)
# Chunk 457: harmonized_chunk shape = (0, 0)
# Chunk 458: harmonized_chunk shape = (0, 0)
# Chunk 459: harmonized_chunk shape = (0, 0)
# Chunk 460: harmonized_chunk shape = (0, 0)
# Chunk 461: harmonized_chunk shape = (0, 0)
# Chunk 462: harmonized_chunk shape = (0, 0)
# Chunk 463: harmonized_chunk shape = (0, 0)
# Chunk 464: harmonized_chunk shape = (0, 0)
# Chunk 465: harmonized_chunk shape = (0, 0)
# Chunk 466: harmonized_chunk shape = (0, 0)
# Chunk 467: harmonized_chunk shape = (0, 0)
# Chunk 468: harmonized_chunk shape = (0, 0)
# Chunk 469: harmonized_chunk shape = (0, 0)
# Chunk 470: harmonized_chunk shape = (0, 0)
# Chunk 471: harmonized_chunk shape = (0, 0)
# Chunk 472: harmonized_chunk shape = (0, 0)
# Chunk 473: harmonized_chunk shape = (0, 0)
# Chunk 474: harmonized_chunk shape = (0, 0)
# Chunk 475: harmonized_chunk shape = (0, 0)
# Chunk 476: harmonized_chunk shape = (0, 0)
# Chunk 477: harmonized_chunk shape = (0, 0)
# Chunk 478: harmonized_chunk shape = (0, 0)
# Chunk 479: harmonized_chunk shape = (0, 0)
# Chunk 480: harmonized_chunk shape = (0, 0)
# Chunk 481: harmonized_chunk shape = (0, 0)
# Chunk 482: harmonized_chunk shape = (0, 0)
# Chunk 483: harmonized_chunk shape = (0, 0)
# Chunk 484: harmonized_chunk shape = (0, 0)
# Chunk 485: harmonized_chunk shape = (0, 0)
# Chunk 486: harmonized_chunk shape = (0, 0)
# Chunk 487: harmonized_chunk shape = (0, 0)
# Chunk 488: harmonized_chunk shape = (0, 0)
# Chunk 489: harmonized_chunk shape = (0, 0)
# Chunk 490: harmonized_chunk shape = (0, 0)
# Chunk 491: harmonized_chunk shape = (0, 0)
# Chunk 492: harmonized_chunk shape = (0, 0)
# Chunk 493: harmonized_chunk shape = (0, 0)
# Chunk 494: harmonized_chunk shape = (0, 0)
# Chunk 495: harmonized_chunk shape = (0, 0)
# Chunk 496: harmonized_chunk shape = (0, 0)
# Chunk 497: harmonized_chunk shape = (0, 0)
# Chunk 498: harmonized_chunk shape = (0, 0)
# Chunk 499: harmonized_chunk shape = (0, 0)
# Chunk 500: harmonized_chunk shape = (0, 0)
# Chunk 501: harmonized_chunk shape = (0, 0)
# Chunk 502: harmonized_chunk shape = (0, 0)
# Chunk 503: harmonized_chunk shape = (0, 0)
# Chunk 504: harmonized_chunk shape = (0, 0)
# Chunk 505: harmonized_chunk shape = (0, 0)
# Chunk 506: harmonized_chunk shape = (0, 0)
# Chunk 507: harmonized_chunk shape = (0, 0)
# Chunk 508: harmonized_chunk shape = (0, 0)
# Chunk 509: harmonized_chunk shape = (0, 0)
# Chunk 510: harmonized_chunk shape = (0, 0)
# Chunk 511: harmonized_chunk shape = (0, 0)
# Chunk 512: harmonized_chunk shape = (0, 0)
# Chunk 513: harmonized_chunk shape = (0, 0)
# Chunk 514: harmonized_chunk shape = (0, 0)
# Chunk 515: harmonized_chunk shape = (0, 0)
# Chunk 516: harmonized_chunk shape = (0, 0)
# Chunk 517: harmonized_chunk shape = (0, 0)
# Chunk 518: harmonized_chunk shape = (0, 0)
# Chunk 519: harmonized_chunk shape = (0, 0)
# Chunk 520: harmonized_chunk shape = (0, 0)
# Chunk 521: harmonized_chunk shape = (0, 0)
# Chunk 522: harmonized_chunk shape = (0, 0)
# Chunk 523: harmonized_chunk shape = (0, 0)
# Chunk 524: harmonized_chunk shape = (0, 0)
# Chunk 525: harmonized_chunk shape = (0, 0)
# Chunk 526: harmonized_chunk shape = (0, 0)
# Chunk 527: harmonized_chunk shape = (0, 0)
# Chunk 528: harmonized_chunk shape = (0, 0)
# Chunk 529: harmonized_chunk shape = (0, 0)
# Chunk 530: harmonized_chunk shape = (0, 0)
# Chunk 531: harmonized_chunk shape = (0, 0)
# Chunk 532: harmonized_chunk shape = (0, 0)
# Chunk 533: harmonized_chunk shape = (0, 0)
# Chunk 534: harmonized_chunk shape = (0, 0)
# Chunk 535: harmonized_chunk shape = (0, 0)
# Chunk 536: harmonized_chunk shape = (0, 0)
# Chunk 537: harmonized_chunk shape = (0, 0)
# Chunk 538: harmonized_chunk shape = (0, 0)
# Chunk 539: harmonized_chunk shape = (0, 0)
# Chunk 540: harmonized_chunk shape = (0, 0)
# Chunk 541: harmonized_chunk shape = (0, 0)
# Chunk 542: harmonized_chunk shape = (0, 0)
# Chunk 543: harmonized_chunk shape = (0, 0)
# Chunk 544: harmonized_chunk shape = (0, 0)
# Chunk 545: harmonized_chunk shape = (0, 0)
# Chunk 546: harmonized_chunk shape = (0, 0)
# Chunk 547: harmonized_chunk shape = (0, 0)
# Chunk 548: harmonized_chunk shape = (0, 0)
# Chunk 549: harmonized_chunk shape = (0, 0)
# Chunk 550: harmonized_chunk shape = (0, 0)
# Chunk 551: harmonized_chunk shape = (0, 0)
# Chunk 552: harmonized_chunk shape = (0, 0)
# Chunk 553: harmonized_chunk shape = (0, 0)
# Chunk 554: harmonized_chunk shape = (0, 0)
# Chunk 555: harmonized_chunk shape = (0, 0)
# Chunk 556: harmonized_chunk shape = (0, 0)
# Chunk 557: harmonized_chunk shape = (0, 0)
# Chunk 558: harmonized_chunk shape = (0, 0)
# Chunk 559: harmonized_chunk shape = (0, 0)
# Chunk 560: harmonized_chunk shape = (0, 0)
# Chunk 561: harmonized_chunk shape = (0, 0)
# Chunk 562: harmonized_chunk shape = (0, 0)
# Chunk 563: harmonized_chunk shape = (0, 0)
# Chunk 564: harmonized_chunk shape = (0, 0)
# Chunk 565: harmonized_chunk shape = (0, 0)
# Chunk 566: harmonized_chunk shape = (0, 0)
# Chunk 567: harmonized_chunk shape = (0, 0)
# Chunk 568: harmonized_chunk shape = (0, 0)
# Chunk 569: harmonized_chunk shape = (0, 0)
# Chunk 570: harmonized_chunk shape = (0, 0)
# Chunk 571: harmonized_chunk shape = (0, 0)
# Chunk 572: harmonized_chunk shape = (0, 0)
# Chunk 573: harmonized_chunk shape = (0, 0)
# Chunk 574: harmonized_chunk shape = (0, 0)
# Chunk 575: harmonized_chunk shape = (0, 0)
# Chunk 576: harmonized_chunk shape = (0, 0)
# Chunk 577: harmonized_chunk shape = (0, 0)
# Chunk 578: harmonized_chunk shape = (0, 0)
# Chunk 579: harmonized_chunk shape = (0, 0)
# Chunk 580: harmonized_chunk shape = (0, 0)
# Chunk 581: harmonized_chunk shape = (0, 0)
# Chunk 582: harmonized_chunk shape = (0, 0)
# Chunk 583: harmonized_chunk shape = (0, 0)
# Chunk 584: harmonized_chunk shape = (0, 0)
# Chunk 585: harmonized_chunk shape = (0, 0)
# Chunk 586: harmonized_chunk shape = (0, 0)
# Chunk 587: harmonized_chunk shape = (0, 0)
# Chunk 588: harmonized_chunk shape = (0, 0)
# Chunk 589: harmonized_chunk shape = (0, 0)
# Chunk 590: harmonized_chunk shape = (0, 0)
# Chunk 591: harmonized_chunk shape = (0, 0)
# Chunk 592: harmonized_chunk shape = (0, 0)
# Chunk 593: harmonized_chunk shape = (0, 0)
# Chunk 594: harmonized_chunk shape = (0, 0)
# Chunk 595: harmonized_chunk shape = (0, 0)
# Chunk 596: harmonized_chunk shape = (0, 0)
# Chunk 597: harmonized_chunk shape = (0, 0)
# Chunk 598: harmonized_chunk shape = (0, 0)
# Chunk 599: harmonized_chunk shape = (0, 0)
# Chunk 600: harmonized_chunk shape = (0, 0)
# Chunk 601: harmonized_chunk shape = (0, 0)
# Chunk 602: harmonized_chunk shape = (0, 0)
# Chunk 603: harmonized_chunk shape = (0, 0)
# Chunk 604: harmonized_chunk shape = (0, 0)
# Chunk 605: harmonized_chunk shape = (0, 0)
# Chunk 606: harmonized_chunk shape = (0, 0)
# Chunk 607: harmonized_chunk shape = (0, 0)
# Chunk 608: harmonized_chunk shape = (0, 0)
# Chunk 609: harmonized_chunk shape = (0, 0)
# Chunk 610: harmonized_chunk shape = (0, 0)
# Chunk 611: harmonized_chunk shape = (0, 0)
# Chunk 612: harmonized_chunk shape = (0, 0)
# Chunk 613: harmonized_chunk shape = (0, 0)
# Chunk 614: harmonized_chunk shape = (0, 0)
# Chunk 615: harmonized_chunk shape = (0, 0)
# Chunk 616: harmonized_chunk shape = (0, 0)
# Chunk 617: harmonized_chunk shape = (0, 0)
# Chunk 618: harmonized_chunk shape = (0, 0)
# Chunk 619: harmonized_chunk shape = (0, 0)
# Chunk 620: harmonized_chunk shape = (0, 0)
# Chunk 621: harmonized_chunk shape = (0, 0)
# Chunk 622: harmonized_chunk shape = (0, 0)
# Chunk 623: harmonized_chunk shape = (0, 0)
# Chunk 624: harmonized_chunk shape = (0, 0)
# Chunk 625: harmonized_chunk shape = (0, 0)
# Chunk 626: harmonized_chunk shape = (0, 0)
# Chunk 627: harmonized_chunk shape = (0, 0)
# Chunk 628: harmonized_chunk shape = (0, 0)
# Chunk 629: harmonized_chunk shape = (0, 0)
# Chunk 630: harmonized_chunk shape = (0, 0)
# Chunk 631: harmonized_chunk shape = (0, 0)
# Chunk 632: harmonized_chunk shape = (0, 0)
# Chunk 633: harmonized_chunk shape = (0, 0)
# Chunk 634: harmonized_chunk shape = (0, 0)
# Chunk 635: harmonized_chunk shape = (0, 0)
# Chunk 636: harmonized_chunk shape = (0, 0)
# Chunk 637: harmonized_chunk shape = (0, 0)
# Chunk 638: harmonized_chunk shape = (0, 0)
# Chunk 639: harmonized_chunk shape = (0, 0)
# Chunk 640: harmonized_chunk shape = (0, 0)
# Chunk 641: harmonized_chunk shape = (0, 0)
# Chunk 642: harmonized_chunk shape = (0, 0)
# Chunk 643: harmonized_chunk shape = (0, 0)
# Chunk 644: harmonized_chunk shape = (0, 0)
# Chunk 645: harmonized_chunk shape = (0, 0)
# Chunk 646: harmonized_chunk shape = (0, 0)
# Chunk 647: harmonized_chunk shape = (0, 0)
# Chunk 648: harmonized_chunk shape = (0, 0)
# Chunk 649: harmonized_chunk shape = (0, 0)
# Chunk 650: harmonized_chunk shape = (0, 0)
# Chunk 651: harmonized_chunk shape = (0, 0)
# Chunk 652: harmonized_chunk shape = (0, 0)
# Chunk 653: harmonized_chunk shape = (0, 0)
# Chunk 654: harmonized_chunk shape = (0, 0)
# Chunk 655: harmonized_chunk shape = (0, 0)
# Chunk 656: harmonized_chunk shape = (0, 0)
# Chunk 657: harmonized_chunk shape = (0, 0)
# Chunk 658: harmonized_chunk shape = (0, 0)
# Chunk 659: harmonized_chunk shape = (0, 0)
# Chunk 660: harmonized_chunk shape = (0, 0)
# Chunk 661: harmonized_chunk shape = (0, 0)
# Chunk 662: harmonized_chunk shape = (0, 0)
# Chunk 663: harmonized_chunk shape = (0, 0)
# Chunk 664: harmonized_chunk shape = (0, 0)
# Chunk 665: harmonized_chunk shape = (0, 0)
# Chunk 666: harmonized_chunk shape = (0, 0)
# Chunk 667: harmonized_chunk shape = (0, 0)
# Chunk 668: harmonized_chunk shape = (0, 0)
# Chunk 669: harmonized_chunk shape = (0, 0)
# Chunk 670: harmonized_chunk shape = (0, 0)
# Chunk 671: harmonized_chunk shape = (0, 0)
# Chunk 672: harmonized_chunk shape = (0, 0)
# Chunk 673: harmonized_chunk shape = (0, 0)
# Chunk 674: harmonized_chunk shape = (0, 0)
# Chunk 675: harmonized_chunk shape = (0, 0)
# Chunk 676: harmonized_chunk shape = (0, 0)
# Chunk 677: harmonized_chunk shape = (0, 0)
# Chunk 678: harmonized_chunk shape = (0, 0)
# Chunk 679: harmonized_chunk shape = (0, 0)
# Chunk 680: harmonized_chunk shape = (0, 0)
# Chunk 681: harmonized_chunk shape = (0, 0)
# Chunk 682: harmonized_chunk shape = (0, 0)
# Chunk 683: harmonized_chunk shape = (0, 0)
# Chunk 684: harmonized_chunk shape = (0, 0)
# Chunk 685: harmonized_chunk shape = (0, 0)
# Chunk 686: harmonized_chunk shape = (0, 0)
# Chunk 687: harmonized_chunk shape = (0, 0)
# Chunk 688: harmonized_chunk shape = (0, 0)
# Chunk 689: harmonized_chunk shape = (0, 0)
# Chunk 690: harmonized_chunk shape = (0, 0)
# Chunk 691: harmonized_chunk shape = (0, 0)
# Chunk 692: harmonized_chunk shape = (0, 0)
# Chunk 693: harmonized_chunk shape = (0, 0)
# Chunk 694: harmonized_chunk shape = (0, 0)
# Chunk 695: harmonized_chunk shape = (0, 0)
# Chunk 696: harmonized_chunk shape = (0, 0)
# Chunk 697: harmonized_chunk shape = (0, 0)
# Chunk 698: harmonized_chunk shape = (0, 0)
# Chunk 699: harmonized_chunk shape = (0, 0)
# Chunk 700: harmonized_chunk shape = (0, 0)
# Chunk 701: harmonized_chunk shape = (0, 0)
# Chunk 702: harmonized_chunk shape = (0, 0)
# Chunk 703: harmonized_chunk shape = (0, 0)
# Chunk 704: harmonized_chunk shape = (0, 0)
# Chunk 705: harmonized_chunk shape = (0, 0)
# Chunk 706: harmonized_chunk shape = (0, 0)
# Chunk 707: harmonized_chunk shape = (0, 0)
# Chunk 708: harmonized_chunk shape = (0, 0)
# Chunk 709: harmonized_chunk shape = (0, 0)
# Chunk 710: harmonized_chunk shape = (0, 0)
# Chunk 711: harmonized_chunk shape = (0, 0)
# Chunk 712: harmonized_chunk shape = (0, 0)
# Chunk 713: harmonized_chunk shape = (0, 0)
# Chunk 714: harmonized_chunk shape = (0, 0)
# Chunk 715: harmonized_chunk shape = (0, 0)
# Chunk 716: harmonized_chunk shape = (0, 0)
# Chunk 717: harmonized_chunk shape = (0, 0)
# Chunk 718: harmonized_chunk shape = (0, 0)
# Chunk 719: harmonized_chunk shape = (0, 0)
# Chunk 720: harmonized_chunk shape = (0, 0)
# Chunk 721: harmonized_chunk shape = (0, 0)
# Chunk 722: harmonized_chunk shape = (0, 0)
# Chunk 723: harmonized_chunk shape = (0, 0)
# Chunk 724: harmonized_chunk shape = (0, 0)
# Chunk 725: harmonized_chunk shape = (0, 0)
# Chunk 726: harmonized_chunk shape = (0, 0)
# Chunk 727: harmonized_chunk shape = (0, 0)
# Chunk 728: harmonized_chunk shape = (0, 0)
# Chunk 729: harmonized_chunk shape = (0, 0)
# Chunk 730: harmonized_chunk shape = (0, 0)
# Chunk 731: harmonized_chunk shape = (0, 0)
# Chunk 732: harmonized_chunk shape = (0, 0)
# Chunk 733: harmonized_chunk shape = (0, 0)
# Chunk 734: harmonized_chunk shape = (0, 0)
# Chunk 735: harmonized_chunk shape = (0, 0)
# Chunk 736: harmonized_chunk shape = (0, 0)
# Chunk 737: harmonized_chunk shape = (0, 0)
# Chunk 738: harmonized_chunk shape = (0, 0)
# Chunk 739: harmonized_chunk shape = (0, 0)
# Chunk 740: harmonized_chunk shape = (0, 0)
# Chunk 741: harmonized_chunk shape = (0, 0)
# Chunk 742: harmonized_chunk shape = (0, 0)
# Chunk 743: harmonized_chunk shape = (0, 0)
# Chunk 744: harmonized_chunk shape = (0, 0)
# Chunk 745: harmonized_chunk shape = (0, 0)
# Chunk 746: harmonized_chunk shape = (0, 0)
# Chunk 747: harmonized_chunk shape = (0, 0)
# Chunk 748: harmonized_chunk shape = (0, 0)
# Chunk 749: harmonized_chunk shape = (0, 0)
# Chunk 750: harmonized_chunk shape = (0, 0)
# Chunk 751: harmonized_chunk shape = (0, 0)
# Chunk 752: harmonized_chunk shape = (0, 0)
# Chunk 753: harmonized_chunk shape = (0, 0)
# Chunk 754: harmonized_chunk shape = (0, 0)
# Chunk 755: harmonized_chunk shape = (0, 0)
# Chunk 756: harmonized_chunk shape = (0, 0)
# Chunk 757: harmonized_chunk shape = (0, 0)
# Chunk 758: harmonized_chunk shape = (0, 0)
# Chunk 759: harmonized_chunk shape = (0, 0)
# Chunk 760: harmonized_chunk shape = (0, 0)
# Chunk 761: harmonized_chunk shape = (0, 0)
# Chunk 762: harmonized_chunk shape = (0, 0)
# Chunk 763: harmonized_chunk shape = (0, 0)
# Chunk 764: harmonized_chunk shape = (0, 0)
# Chunk 765: harmonized_chunk shape = (0, 0)
# Chunk 766: harmonized_chunk shape = (0, 0)
# Chunk 767: harmonized_chunk shape = (0, 0)
# Chunk 768: harmonized_chunk shape = (0, 0)
# Chunk 769: harmonized_chunk shape = (0, 0)
# Chunk 770: harmonized_chunk shape = (0, 0)
# Chunk 771: harmonized_chunk shape = (0, 0)
# Chunk 772: harmonized_chunk shape = (0, 0)
# Chunk 773: harmonized_chunk shape = (0, 0)
# Chunk 774: harmonized_chunk shape = (0, 0)
# Chunk 775: harmonized_chunk shape = (0, 0)
# Chunk 776: harmonized_chunk shape = (0, 0)
# Chunk 777: harmonized_chunk shape = (0, 0)
# Chunk 778: harmonized_chunk shape = (0, 0)
# Chunk 779: harmonized_chunk shape = (0, 0)
# Chunk 780: harmonized_chunk shape = (0, 0)
# Chunk 781: harmonized_chunk shape = (0, 0)
# Chunk 782: harmonized_chunk shape = (0, 0)
# Chunk 783: harmonized_chunk shape = (0, 0)
# Chunk 784: harmonized_chunk shape = (0, 0)
# Chunk 785: harmonized_chunk shape = (0, 0)
# Chunk 786: harmonized_chunk shape = (0, 0)
# Chunk 787: harmonized_chunk shape = (0, 0)
# Chunk 788: harmonized_chunk shape = (0, 0)
# Chunk 789: harmonized_chunk shape = (0, 0)
# Chunk 790: harmonized_chunk shape = (0, 0)
# Chunk 791: harmonized_chunk shape = (0, 0)
# Chunk 792: harmonized_chunk shape = (0, 0)
# Chunk 793: harmonized_chunk shape = (0, 0)
# Chunk 794: harmonized_chunk shape = (0, 0)
# Chunk 795: harmonized_chunk shape = (0, 0)
# Chunk 796: harmonized_chunk shape = (0, 0)
# Chunk 797: harmonized_chunk shape = (0, 0)
# Chunk 798: harmonized_chunk shape = (0, 0)
# Chunk 799: harmonized_chunk shape = (0, 0)
# Chunk 800: harmonized_chunk shape = (0, 0)
# Chunk 801: harmonized_chunk shape = (0, 0)
# Chunk 802: harmonized_chunk shape = (0, 0)
# Chunk 803: harmonized_chunk shape = (0, 0)
# Chunk 804: harmonized_chunk shape = (0, 0)
# Chunk 805: harmonized_chunk shape = (0, 0)
# Chunk 806: harmonized_chunk shape = (0, 0)
# Chunk 807: harmonized_chunk shape = (0, 0)
# Chunk 808: harmonized_chunk shape = (0, 0)
# Chunk 809: harmonized_chunk shape = (0, 0)
# Chunk 810: harmonized_chunk shape = (0, 0)
# Chunk 811: harmonized_chunk shape = (0, 0)
# Chunk 812: harmonized_chunk shape = (0, 0)
# Chunk 813: harmonized_chunk shape = (0, 0)
# Chunk 814: harmonized_chunk shape = (0, 0)
# Chunk 815: harmonized_chunk shape = (0, 0)
# Chunk 816: harmonized_chunk shape = (0, 0)
# Chunk 817: harmonized_chunk shape = (0, 0)
# Chunk 818: harmonized_chunk shape = (0, 0)
# Chunk 819: harmonized_chunk shape = (0, 0)
# Chunk 820: harmonized_chunk shape = (0, 0)
# Chunk 821: harmonized_chunk shape = (0, 0)
# Chunk 822: harmonized_chunk shape = (0, 0)
# Chunk 823: harmonized_chunk shape = (0, 0)
# Chunk 824: harmonized_chunk shape = (0, 0)
# Chunk 825: harmonized_chunk shape = (0, 0)
# Chunk 826: harmonized_chunk shape = (0, 0)
# Chunk 827: harmonized_chunk shape = (0, 0)
# Chunk 828: harmonized_chunk shape = (0, 0)
# Chunk 829: harmonized_chunk shape = (0, 0)
# Chunk 830: harmonized_chunk shape = (0, 0)
# Chunk 831: harmonized_chunk shape = (0, 0)
# Chunk 832: harmonized_chunk shape = (0, 0)
# Chunk 833: harmonized_chunk shape = (0, 0)
# Chunk 834: harmonized_chunk shape = (0, 0)
# Chunk 835: harmonized_chunk shape = (0, 0)
# Chunk 836: harmonized_chunk shape = (0, 0)
# Chunk 837: harmonized_chunk shape = (0, 0)
# Chunk 838: harmonized_chunk shape = (0, 0)
# Chunk 839: harmonized_chunk shape = (0, 0)
# Chunk 840: harmonized_chunk shape = (0, 0)
# Chunk 841: harmonized_chunk shape = (0, 0)
# Chunk 842: harmonized_chunk shape = (0, 0)
# Chunk 843: harmonized_chunk shape = (0, 0)
# Chunk 844: harmonized_chunk shape = (0, 0)
# Chunk 845: harmonized_chunk shape = (0, 0)
# Chunk 846: harmonized_chunk shape = (0, 0)
# Chunk 847: harmonized_chunk shape = (0, 0)
# Chunk 848: harmonized_chunk shape = (0, 0)
# Chunk 849: harmonized_chunk shape = (0, 0)
# Chunk 850: harmonized_chunk shape = (0, 0)
# Chunk 851: harmonized_chunk shape = (0, 0)
# Chunk 852: harmonized_chunk shape = (0, 0)
# Chunk 853: harmonized_chunk shape = (0, 0)
# Chunk 854: harmonized_chunk shape = (0, 0)
# Chunk 855: harmonized_chunk shape = (0, 0)
# Chunk 856: harmonized_chunk shape = (0, 0)
# Chunk 857: harmonized_chunk shape = (0, 0)
# Chunk 858: harmonized_chunk shape = (0, 0)
# Chunk 859: harmonized_chunk shape = (0, 0)
# Chunk 860: harmonized_chunk shape = (0, 0)
# Chunk 861: harmonized_chunk shape = (0, 0)
# Chunk 862: harmonized_chunk shape = (0, 0)
# Chunk 863: harmonized_chunk shape = (0, 0)
# Chunk 864: harmonized_chunk shape = (0, 0)
# Chunk 865: harmonized_chunk shape = (0, 0)
# Chunk 866: harmonized_chunk shape = (0, 0)
# Chunk 867: harmonized_chunk shape = (0, 0)
# Chunk 868: harmonized_chunk shape = (0, 0)
# Chunk 869: harmonized_chunk shape = (0, 0)
# Chunk 870: harmonized_chunk shape = (0, 0)
# Chunk 871: harmonized_chunk shape = (0, 0)
# Chunk 872: harmonized_chunk shape = (0, 0)
# Chunk 873: harmonized_chunk shape = (0, 0)
# Chunk 874: harmonized_chunk shape = (0, 0)
# Chunk 875: harmonized_chunk shape = (0, 0)
# Chunk 876: harmonized_chunk shape = (0, 0)
# Chunk 877: harmonized_chunk shape = (0, 0)
# Chunk 878: harmonized_chunk shape = (0, 0)
# Chunk 879: harmonized_chunk shape = (0, 0)
# Chunk 880: harmonized_chunk shape = (0, 0)
# Chunk 881: harmonized_chunk shape = (0, 0)
# Chunk 882: harmonized_chunk shape = (0, 0)
# Chunk 883: harmonized_chunk shape = (0, 0)
# Chunk 884: harmonized_chunk shape = (0, 0)
# Chunk 885: harmonized_chunk shape = (0, 0)
# Chunk 886: harmonized_chunk shape = (0, 0)
# Chunk 887: harmonized_chunk shape = (0, 0)
# Chunk 888: harmonized_chunk shape = (0, 0)
# Chunk 889: harmonized_chunk shape = (0, 0)
# Chunk 890: harmonized_chunk shape = (0, 0)
# Chunk 891: harmonized_chunk shape = (0, 0)
# Chunk 892: harmonized_chunk shape = (0, 0)
# Chunk 893: harmonized_chunk shape = (0, 0)
# Chunk 894: harmonized_chunk shape = (0, 0)
# Chunk 895: harmonized_chunk shape = (0, 0)
# Chunk 896: harmonized_chunk shape = (0, 0)
# Chunk 897: harmonized_chunk shape = (0, 0)
# Chunk 898: harmonized_chunk shape = (0, 0)
# Chunk 899: harmonized_chunk shape = (0, 0)
# Chunk 900: harmonized_chunk shape = (0, 0)
# Chunk 901: harmonized_chunk shape = (0, 0)
# Chunk 902: harmonized_chunk shape = (0, 0)
# Chunk 903: harmonized_chunk shape = (0, 0)
# Chunk 904: harmonized_chunk shape = (0, 0)
# Chunk 905: harmonized_chunk shape = (0, 0)
# Chunk 906: harmonized_chunk shape = (0, 0)
# Chunk 907: harmonized_chunk shape = (0, 0)
# Chunk 908: harmonized_chunk shape = (0, 0)
# Chunk 909: harmonized_chunk shape = (0, 0)
# Chunk 910: harmonized_chunk shape = (0, 0)
# Chunk 911: harmonized_chunk shape = (0, 0)
# Chunk 912: harmonized_chunk shape = (0, 0)
# Chunk 913: harmonized_chunk shape = (0, 0)
# Chunk 914: harmonized_chunk shape = (0, 0)
# Chunk 915: harmonized_chunk shape = (0, 0)
# Chunk 916: harmonized_chunk shape = (0, 0)
# Chunk 917: harmonized_chunk shape = (0, 0)
# Chunk 918: harmonized_chunk shape = (0, 0)
# Chunk 919: harmonized_chunk shape = (0, 0)
# Chunk 920: harmonized_chunk shape = (0, 0)
# Chunk 921: harmonized_chunk shape = (0, 0)
# Chunk 922: harmonized_chunk shape = (0, 0)
# Chunk 923: harmonized_chunk shape = (0, 0)
# Chunk 924: harmonized_chunk shape = (0, 0)
# Chunk 925: harmonized_chunk shape = (0, 0)
# Chunk 926: harmonized_chunk shape = (0, 0)
# Chunk 927: harmonized_chunk shape = (0, 0)
# Chunk 928: harmonized_chunk shape = (0, 0)
# Chunk 929: harmonized_chunk shape = (0, 0)
# Chunk 930: harmonized_chunk shape = (0, 0)
# Chunk 931: harmonized_chunk shape = (0, 0)
# Chunk 932: harmonized_chunk shape = (0, 0)
# Chunk 933: harmonized_chunk shape = (0, 0)
# Chunk 934: harmonized_chunk shape = (0, 0)
# Chunk 935: harmonized_chunk shape = (0, 0)
# Chunk 936: harmonized_chunk shape = (0, 0)
# Chunk 937: harmonized_chunk shape = (0, 0)
# Chunk 938: harmonized_chunk shape = (0, 0)
# Chunk 939: harmonized_chunk shape = (0, 0)
# Chunk 940: harmonized_chunk shape = (0, 0)
# Chunk 941: harmonized_chunk shape = (0, 0)
# Chunk 942: harmonized_chunk shape = (0, 0)
# Chunk 943: harmonized_chunk shape = (0, 0)
# Chunk 944: harmonized_chunk shape = (0, 0)
# Chunk 945: harmonized_chunk shape = (0, 0)
# Chunk 946: harmonized_chunk shape = (0, 0)
# Chunk 947: harmonized_chunk shape = (0, 0)
# Chunk 948: harmonized_chunk shape = (0, 0)
# Chunk 949: harmonized_chunk shape = (0, 0)
# Chunk 950: harmonized_chunk shape = (0, 0)
# Chunk 951: harmonized_chunk shape = (0, 0)
# Chunk 952: harmonized_chunk shape = (0, 0)
# Chunk 953: harmonized_chunk shape = (0, 0)
# Chunk 954: harmonized_chunk shape = (0, 0)
# Chunk 955: harmonized_chunk shape = (0, 0)
# Chunk 956: harmonized_chunk shape = (0, 0)
# Chunk 957: harmonized_chunk shape = (0, 0)
# Chunk 958: harmonized_chunk shape = (0, 0)
# Chunk 959: harmonized_chunk shape = (0, 0)
# Chunk 960: harmonized_chunk shape = (0, 0)
# Chunk 961: harmonized_chunk shape = (0, 0)
# Chunk 962: harmonized_chunk shape = (0, 0)
# Chunk 963: harmonized_chunk shape = (0, 0)
# Chunk 964: harmonized_chunk shape = (0, 0)
# Chunk 965: harmonized_chunk shape = (0, 0)
# Chunk 966: harmonized_chunk shape = (0, 0)
# Chunk 967: harmonized_chunk shape = (0, 0)
# Chunk 968: harmonized_chunk shape = (0, 0)
# Chunk 969: harmonized_chunk shape = (0, 0)
# Chunk 970: harmonized_chunk shape = (0, 0)
# Chunk 971: harmonized_chunk shape = (0, 0)
# Chunk 972: harmonized_chunk shape = (0, 0)
# Chunk 973: harmonized_chunk shape = (0, 0)
# Chunk 974: harmonized_chunk shape = (0, 0)
# Chunk 975: harmonized_chunk shape = (0, 0)
# Chunk 976: harmonized_chunk shape = (0, 0)
# Chunk 977: harmonized_chunk shape = (0, 0)
# Chunk 978: harmonized_chunk shape = (0, 0)
# Chunk 979: harmonized_chunk shape = (0, 0)
# Chunk 980: harmonized_chunk shape = (0, 0)
# Chunk 981: harmonized_chunk shape = (0, 0)
# Chunk 982: harmonized_chunk shape = (0, 0)
# Chunk 983: harmonized_chunk shape = (0, 0)
# Chunk 984: harmonized_chunk shape = (0, 0)
# Chunk 985: harmonized_chunk shape = (0, 0)
# Chunk 986: harmonized_chunk shape = (0, 0)
# Chunk 987: harmonized_chunk shape = (0, 0)
# Chunk 988: harmonized_chunk shape = (0, 0)
# Chunk 989: harmonized_chunk shape = (0, 0)
# Chunk 990: harmonized_chunk shape = (0, 0)
# Chunk 991: harmonized_chunk shape = (0, 0)
# Chunk 992: harmonized_chunk shape = (0, 0)
# Chunk 993: harmonized_chunk shape = (0, 0)
# Chunk 994: harmonized_chunk shape = (0, 0)
# Chunk 995: harmonized_chunk shape = (0, 0)
# Chunk 996: harmonized_chunk shape = (0, 0)
# Chunk 997: harmonized_chunk shape = (0, 0)
# Chunk 998: harmonized_chunk shape = (0, 0)
# Chunk 999: harmonized_chunk shape = (0, 0)
# Chunk 1000: harmonized_chunk shape = (0, 0)
# Chunk 1001: harmonized_chunk shape = (0, 0)
# Chunk 1002: harmonized_chunk shape = (0, 0)
# Chunk 1003: harmonized_chunk shape = (0, 0)
# Chunk 1004: harmonized_chunk shape = (0, 0)
# Chunk 1005: harmonized_chunk shape = (0, 0)
# Chunk 1006: harmonized_chunk shape = (0, 0)
# Chunk 1007: harmonized_chunk shape = (0, 0)
# Chunk 1008: harmonized_chunk shape = (0, 0)
# Chunk 1009: harmonized_chunk shape = (0, 0)
# Chunk 1010: harmonized_chunk shape = (0, 0)
# Chunk 1011: harmonized_chunk shape = (0, 0)
# Chunk 1012: harmonized_chunk shape = (0, 0)
# Chunk 1013: harmonized_chunk shape = (0, 0)
# Chunk 1014: harmonized_chunk shape = (0, 0)
# Chunk 1015: harmonized_chunk shape = (0, 0)
# Chunk 1016: harmonized_chunk shape = (0, 0)
# Chunk 1017: harmonized_chunk shape = (0, 0)
# Chunk 1018: harmonized_chunk shape = (0, 0)
# Chunk 1019: harmonized_chunk shape = (0, 0)
# Chunk 1020: harmonized_chunk shape = (0, 0)
# Chunk 1021: harmonized_chunk shape = (0, 0)
# Chunk 1022: harmonized_chunk shape = (0, 0)
# Chunk 1023: harmonized_chunk shape = (0, 0)
# Chunk 1024: harmonized_chunk shape = (0, 0)
# Chunk 1025: harmonized_chunk shape = (0, 0)
# Chunk 1026: harmonized_chunk shape = (0, 0)
# Chunk 1027: harmonized_chunk shape = (0, 0)
# Chunk 1028: harmonized_chunk shape = (0, 0)
# Chunk 1029: harmonized_chunk shape = (0, 0)
# Chunk 1030: harmonized_chunk shape = (0, 0)
# Chunk 1031: harmonized_chunk shape = (0, 0)
# Chunk 1032: harmonized_chunk shape = (0, 0)
# Chunk 1033: harmonized_chunk shape = (0, 0)
# Chunk 1034: harmonized_chunk shape = (0, 0)
# Chunk 1035: harmonized_chunk shape = (0, 0)
# Chunk 1036: harmonized_chunk shape = (0, 0)
# Chunk 1037: harmonized_chunk shape = (0, 0)
# Chunk 1038: harmonized_chunk shape = (0, 0)
# Chunk 1039: harmonized_chunk shape = (0, 0)
# Chunk 1040: harmonized_chunk shape = (0, 0)
# Chunk 1041: harmonized_chunk shape = (0, 0)
# Chunk 1042: harmonized_chunk shape = (0, 0)
# Chunk 1043: harmonized_chunk shape = (0, 0)
# Chunk 1044: harmonized_chunk shape = (0, 0)
# Chunk 1045: harmonized_chunk shape = (0, 0)
# Chunk 1046: harmonized_chunk shape = (0, 0)
# Chunk 1047: harmonized_chunk shape = (0, 0)
# Chunk 1048: harmonized_chunk shape = (0, 0)
# Chunk 1049: harmonized_chunk shape = (0, 0)
# Chunk 1050: harmonized_chunk shape = (0, 0)
# Chunk 1051: harmonized_chunk shape = (0, 0)
# Chunk 1052: harmonized_chunk shape = (0, 0)
# Chunk 1053: harmonized_chunk shape = (0, 0)
# Chunk 1054: harmonized_chunk shape = (0, 0)
# Chunk 1055: harmonized_chunk shape = (0, 0)
# Chunk 1056: harmonized_chunk shape = (0, 0)
# Chunk 1057: harmonized_chunk shape = (0, 0)
# Chunk 1058: harmonized_chunk shape = (0, 0)
# Chunk 1059: harmonized_chunk shape = (0, 0)
# Chunk 1060: harmonized_chunk shape = (0, 0)
# Chunk 1061: harmonized_chunk shape = (0, 0)
# Chunk 1062: harmonized_chunk shape = (0, 0)
# Chunk 1063: harmonized_chunk shape = (0, 0)
# Chunk 1064: harmonized_chunk shape = (0, 0)
# Chunk 1065: harmonized_chunk shape = (0, 0)
# Chunk 1066: harmonized_chunk shape = (0, 0)
# Chunk 1067: harmonized_chunk shape = (0, 0)
# Chunk 1068: harmonized_chunk shape = (0, 0)
# Chunk 1069: harmonized_chunk shape = (0, 0)
# Chunk 1070: harmonized_chunk shape = (0, 0)
# Chunk 1071: harmonized_chunk shape = (0, 0)
# Chunk 1072: harmonized_chunk shape = (0, 0)
# Chunk 1073: harmonized_chunk shape = (0, 0)
# Chunk 1074: harmonized_chunk shape = (0, 0)
# Chunk 1075: harmonized_chunk shape = (0, 0)
# Chunk 1076: harmonized_chunk shape = (0, 0)
# Chunk 1077: harmonized_chunk shape = (0, 0)
# Chunk 1078: harmonized_chunk shape = (0, 0)
# Chunk 1079: harmonized_chunk shape = (0, 0)
# Chunk 1080: harmonized_chunk shape = (0, 0)
# Chunk 1081: harmonized_chunk shape = (0, 0)
# Chunk 1082: harmonized_chunk shape = (0, 0)
# Chunk 1083: harmonized_chunk shape = (0, 0)
# Chunk 1084: harmonized_chunk shape = (0, 0)
# Chunk 1085: harmonized_chunk shape = (0, 0)
# Chunk 1086: harmonized_chunk shape = (0, 0)
# Chunk 1087: harmonized_chunk shape = (0, 0)
# Chunk 1088: harmonized_chunk shape = (0, 0)
# Chunk 1089: harmonized_chunk shape = (0, 0)
# Chunk 1090: harmonized_chunk shape = (0, 0)
# Chunk 1091: harmonized_chunk shape = (0, 0)
# Chunk 1092: harmonized_chunk shape = (0, 0)
# Chunk 1093: harmonized_chunk shape = (0, 0)
# Chunk 1094: harmonized_chunk shape = (0, 0)
# Chunk 1095: harmonized_chunk shape = (0, 0)
# Chunk 1096: harmonized_chunk shape = (0, 0)
# Chunk 1097: harmonized_chunk shape = (0, 0)
# Chunk 1098: harmonized_chunk shape = (0, 0)
# Chunk 1099: harmonized_chunk shape = (0, 0)
# Chunk 1100: harmonized_chunk shape = (0, 0)
# Chunk 1101: harmonized_chunk shape = (0, 0)
# Chunk 1102: harmonized_chunk shape = (0, 0)
# Chunk 1103: harmonized_chunk shape = (0, 0)
# Chunk 1104: harmonized_chunk shape = (0, 0)
# Chunk 1105: harmonized_chunk shape = (0, 0)
# Chunk 1106: harmonized_chunk shape = (0, 0)
# Chunk 1107: harmonized_chunk shape = (0, 0)
# Chunk 1108: harmonized_chunk shape = (0, 0)
# Chunk 1109: harmonized_chunk shape = (0, 0)
# Chunk 1110: harmonized_chunk shape = (0, 0)
# Chunk 1111: harmonized_chunk shape = (0, 0)
# Chunk 1112: harmonized_chunk shape = (0, 0)
# Chunk 1113: harmonized_chunk shape = (0, 0)
# Chunk 1114: harmonized_chunk shape = (0, 0)
# Chunk 1115: harmonized_chunk shape = (0, 0)
# Chunk 1116: harmonized_chunk shape = (0, 0)
# Chunk 1117: harmonized_chunk shape = (0, 0)
# Chunk 1118: harmonized_chunk shape = (0, 0)
# Chunk 1119: harmonized_chunk shape = (0, 0)
# Chunk 1120: harmonized_chunk shape = (0, 0)
# Chunk 1121: harmonized_chunk shape = (0, 0)
# Chunk 1122: harmonized_chunk shape = (0, 0)
# Chunk 1123: harmonized_chunk shape = (0, 0)
# Chunk 1124: harmonized_chunk shape = (0, 0)
# Chunk 1125: harmonized_chunk shape = (0, 0)
# Chunk 1126: harmonized_chunk shape = (0, 0)
# Chunk 1127: harmonized_chunk shape = (0, 0)
# Chunk 1128: harmonized_chunk shape = (0, 0)
# Chunk 1129: harmonized_chunk shape = (0, 0)
# Chunk 1130: harmonized_chunk shape = (0, 0)
# Chunk 1131: harmonized_chunk shape = (0, 0)
# Chunk 1132: harmonized_chunk shape = (0, 0)
# Chunk 1133: harmonized_chunk shape = (0, 0)
# Chunk 1134: harmonized_chunk shape = (0, 0)
# Chunk 1135: harmonized_chunk shape = (0, 0)
# Chunk 1136: harmonized_chunk shape = (0, 0)
# Chunk 1137: harmonized_chunk shape = (0, 0)
# Chunk 1138: harmonized_chunk shape = (0, 0)
# Chunk 1139: harmonized_chunk shape = (0, 0)
# Chunk 1140: harmonized_chunk shape = (0, 0)
# Chunk 1141: harmonized_chunk shape = (0, 0)
# Chunk 1142: harmonized_chunk shape = (0, 0)
# Chunk 1143: harmonized_chunk shape = (0, 0)
# Chunk 1144: harmonized_chunk shape = (0, 0)
# Chunk 1145: harmonized_chunk shape = (0, 0)
# Chunk 1146: harmonized_chunk shape = (0, 0)
# Chunk 1147: harmonized_chunk shape = (0, 0)
# Chunk 1148: harmonized_chunk shape = (0, 0)
# Chunk 1149: harmonized_chunk shape = (0, 0)
# Chunk 1150: harmonized_chunk shape = (0, 0)
# Chunk 1151: harmonized_chunk shape = (0, 0)
# Chunk 1152: harmonized_chunk shape = (0, 0)
# Chunk 1153: harmonized_chunk shape = (0, 0)
# Chunk 1154: harmonized_chunk shape = (0, 0)
# Chunk 1155: harmonized_chunk shape = (0, 0)
# Chunk 1156: harmonized_chunk shape = (0, 0)
# Chunk 1157: harmonized_chunk shape = (0, 0)
# Chunk 1158: harmonized_chunk shape = (0, 0)
# Chunk 1159: harmonized_chunk shape = (0, 0)
# Chunk 1160: harmonized_chunk shape = (0, 0)
# Chunk 1161: harmonized_chunk shape = (0, 0)
# Chunk 1162: harmonized_chunk shape = (0, 0)
# Chunk 1163: harmonized_chunk shape = (0, 0)
# Chunk 1164: harmonized_chunk shape = (0, 0)
# Chunk 1165: harmonized_chunk shape = (0, 0)
# Chunk 1166: harmonized_chunk shape = (0, 0)
# Chunk 1167: harmonized_chunk shape = (0, 0)
# Chunk 1168: harmonized_chunk shape = (0, 0)
# Chunk 1169: harmonized_chunk shape = (0, 0)
# Chunk 1170: harmonized_chunk shape = (0, 0)
# Chunk 1171: harmonized_chunk shape = (0, 0)
# Chunk 1172: harmonized_chunk shape = (0, 0)
# Chunk 1173: harmonized_chunk shape = (0, 0)
# Chunk 1174: harmonized_chunk shape = (0, 0)
# Chunk 1175: harmonized_chunk shape = (0, 0)
# Chunk 1176: harmonized_chunk shape = (0, 0)
# Chunk 1177: harmonized_chunk shape = (0, 0)
# Chunk 1178: harmonized_chunk shape = (0, 0)
# Chunk 1179: harmonized_chunk shape = (0, 0)
# Chunk 1180: harmonized_chunk shape = (0, 0)
# Chunk 1181: harmonized_chunk shape = (0, 0)
# Chunk 1182: harmonized_chunk shape = (0, 0)
# Chunk 1183: harmonized_chunk shape = (0, 0)
# Chunk 1184: harmonized_chunk shape = (0, 0)
# Chunk 1185: harmonized_chunk shape = (0, 0)
# Chunk 1186: harmonized_chunk shape = (0, 0)
# Chunk 1187: harmonized_chunk shape = (0, 0)
# Chunk 1188: harmonized_chunk shape = (0, 0)
# Chunk 1189: harmonized_chunk shape = (0, 0)
# Chunk 1190: harmonized_chunk shape = (0, 0)
# Chunk 1191: harmonized_chunk shape = (0, 0)
# Chunk 1192: harmonized_chunk shape = (0, 0)
# Chunk 1193: harmonized_chunk shape = (0, 0)
# Chunk 1194: harmonized_chunk shape = (0, 0)
# Chunk 1195: harmonized_chunk shape = (0, 0)
# Chunk 1196: harmonized_chunk shape = (0, 0)
# Chunk 1197: harmonized_chunk shape = (0, 0)
# Chunk 1198: harmonized_chunk shape = (0, 0)
# Chunk 1199: harmonized_chunk shape = (0, 0)
# Chunk 1200: harmonized_chunk shape = (0, 0)
# Chunk 1201: harmonized_chunk shape = (0, 0)
# Chunk 1202: harmonized_chunk shape = (0, 0)
# Chunk 1203: harmonized_chunk shape = (0, 0)
# Chunk 1204: harmonized_chunk shape = (0, 0)
# Chunk 1205: harmonized_chunk shape = (0, 0)
# Chunk 1206: harmonized_chunk shape = (0, 0)
# Chunk 1207: harmonized_chunk shape = (0, 0)
# Chunk 1208: harmonized_chunk shape = (0, 0)
# Chunk 1209: harmonized_chunk shape = (0, 0)
# Chunk 1210: harmonized_chunk shape = (0, 0)
# Chunk 1211: harmonized_chunk shape = (0, 0)
# Chunk 1212: harmonized_chunk shape = (0, 0)
# Chunk 1213: harmonized_chunk shape = (0, 0)
# Chunk 1214: harmonized_chunk shape = (0, 0)
# Chunk 1215: harmonized_chunk shape = (0, 0)
# Chunk 1216: harmonized_chunk shape = (0, 0)
# Chunk 1217: harmonized_chunk shape = (0, 0)
# Chunk 1218: harmonized_chunk shape = (0, 0)
# Chunk 1219: harmonized_chunk shape = (0, 0)
# Chunk 1220: harmonized_chunk shape = (0, 0)
# Chunk 1221: harmonized_chunk shape = (0, 0)
# Chunk 1222: harmonized_chunk shape = (0, 0)
# Chunk 1223: harmonized_chunk shape = (0, 0)
# Chunk 1224: harmonized_chunk shape = (0, 0)
# Chunk 1225: harmonized_chunk shape = (0, 0)
# Chunk 1226: harmonized_chunk shape = (0, 0)
# Chunk 1227: harmonized_chunk shape = (0, 0)
# Chunk 1228: harmonized_chunk shape = (0, 0)
# Chunk 1229: harmonized_chunk shape = (0, 0)
# Chunk 1230: harmonized_chunk shape = (0, 0)
# Chunk 1231: harmonized_chunk shape = (0, 0)
# Chunk 1232: harmonized_chunk shape = (0, 0)
# Chunk 1233: harmonized_chunk shape = (0, 0)
# Chunk 1234: harmonized_chunk shape = (0, 0)
# Chunk 1235: harmonized_chunk shape = (0, 0)
# Chunk 1236: harmonized_chunk shape = (0, 0)
# Chunk 1237: harmonized_chunk shape = (0, 0)
# Chunk 1238: harmonized_chunk shape = (0, 0)
# Chunk 1239: harmonized_chunk shape = (0, 0)
# Chunk 1240: harmonized_chunk shape = (0, 0)
# Chunk 1241: harmonized_chunk shape = (0, 0)
# Chunk 1242: harmonized_chunk shape = (0, 0)
# Chunk 1243: harmonized_chunk shape = (0, 0)
# Chunk 1244: harmonized_chunk shape = (0, 0)
# Chunk 1245: harmonized_chunk shape = (0, 0)
# Chunk 1246: harmonized_chunk shape = (0, 0)
# Chunk 1247: harmonized_chunk shape = (0, 0)
# Chunk 1248: harmonized_chunk shape = (0, 0)
# Chunk 1249: harmonized_chunk shape = (0, 0)
# Chunk 1250: harmonized_chunk shape = (0, 0)
# Chunk 1251: harmonized_chunk shape = (0, 0)
# Chunk 1252: harmonized_chunk shape = (0, 0)
# Chunk 1253: harmonized_chunk shape = (0, 0)
# Chunk 1254: harmonized_chunk shape = (0, 0)
# Chunk 1255: harmonized_chunk shape = (0, 0)
# Chunk 1256: harmonized_chunk shape = (0, 0)
# Chunk 1257: harmonized_chunk shape = (0, 0)
# Chunk 1258: harmonized_chunk shape = (0, 0)
# Chunk 1259: harmonized_chunk shape = (0, 0)
# Chunk 1260: harmonized_chunk shape = (0, 0)
# Chunk 1261: harmonized_chunk shape = (0, 0)
# Chunk 1262: harmonized_chunk shape = (0, 0)
# Chunk 1263: harmonized_chunk shape = (0, 0)
# Chunk 1264: harmonized_chunk shape = (0, 0)
# Chunk 1265: harmonized_chunk shape = (0, 0)
# Chunk 1266: harmonized_chunk shape = (0, 0)
# Chunk 1267: harmonized_chunk shape = (0, 0)
# Chunk 1268: harmonized_chunk shape = (0, 0)
# Chunk 1269: harmonized_chunk shape = (0, 0)
# Chunk 1270: harmonized_chunk shape = (0, 0)
# Chunk 1271: harmonized_chunk shape = (0, 0)
# Chunk 1272: harmonized_chunk shape = (0, 0)
# Chunk 1273: harmonized_chunk shape = (0, 0)
# Chunk 1274: harmonized_chunk shape = (0, 0)
# Chunk 1275: harmonized_chunk shape = (0, 0)
# Chunk 1276: harmonized_chunk shape = (0, 0)
# Chunk 1277: harmonized_chunk shape = (0, 0)
# Chunk 1278: harmonized_chunk shape = (0, 0)
# Chunk 1279: harmonized_chunk shape = (0, 0)
# Chunk 1280: harmonized_chunk shape = (0, 0)
# Chunk 1281: harmonized_chunk shape = (0, 0)
# Chunk 1282: harmonized_chunk shape = (0, 0)
# Chunk 1283: harmonized_chunk shape = (0, 0)
# Chunk 1284: harmonized_chunk shape = (0, 0)
# Chunk 1285: harmonized_chunk shape = (0, 0)
# Chunk 1286: harmonized_chunk shape = (0, 0)
# Chunk 1287: harmonized_chunk shape = (0, 0)
# Chunk 1288: harmonized_chunk shape = (0, 0)
# Chunk 1289: harmonized_chunk shape = (0, 0)
# Chunk 1290: harmonized_chunk shape = (0, 0)
# Chunk 1291: harmonized_chunk shape = (0, 0)
# Chunk 1292: harmonized_chunk shape = (0, 0)
# Chunk 1293: harmonized_chunk shape = (0, 0)
# No harmonized data found in any chunk. Nothing to concatenate.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 130
#     126     print("No harmonized data found in any chunk. Nothing to concatenate.")
#     129 # Sum over all SNPs for an individual's PGS
# --> 130 total_score = harmonized_df['weighted_score'].sum()
#     132 print(f"Polygenic Score: {total_score}")
#
# File ~\Downloads\Personal_File\University_of_Bradford\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\Downloads\Personal_File\University_of_Bradford\Lib\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'weighted_score'

# %%
pgs_df['SNP'] = pgs_df['SNP'].str.strip().str.upper()
geno_chunk['SNP'] = geno_chunk['SNP'].str.strip().str.upper()
print(geno_chunk.head())
# Out:
#          SNP REF ALT   Sample  dosage
# 12930000   .   C   G  HG00119       0
# 12930001   .   C   G  HG00121       0
# 12930002   .   T   A  HG00119       0
# 12930003   .   T   A  HG00121       0
# 12930004   .   C   T  HG00119       0

# %%
geno_df = pd.read_csv('chr1_genotype_dosage.csv', nrows=10)
print(geno_df)
# Out:
#   SNP REF ALT   Sample  dosage
# 0   .   A  AC  HG00119       0
# 1   .   A  AC  HG00121       0
# 2   .   T  TA  HG00119       0
# 3   .   T  TA  HG00121       0
# 4   .   T  TA  HG00119       0
# 5   .   T  TA  HG00121       0
# 6   .   A   T  HG00119       0
# 7   .   A   T  HG00121       0
# 8   .   C   G  HG00119       0
# 9   .   C   G  HG00121       0
